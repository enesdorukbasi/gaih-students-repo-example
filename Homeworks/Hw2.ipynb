# %%
Kisi1 = {"Mezuniyet":"ÖnLisans","NotDurumu":2.5,"Mesleği":"Yazılımcı"}
Kisi2 = {"Mezuniyet":"YüksekLisans","NotDurumu":3.2,"Mesleği":"Yazılımcı"}
Kisi3 = {"Mezuniyet":"ÖnLisans","NotDurumu":4,"Mesleği":"Yazılımcı"}
Kisi4 = {"Mezuniyet":"ÖnLisans","NotDurumu":3.5,"Mesleği":"Yazılımcı"}
Kisi5 = {"Mezuniyet":"YüksekLisans","NotDurumu":3.8,"Mesleği":"Yazılımcı"}

for i in Kisi1:
  leg1 = Kisi1[i]
  leg2 = Kisi2[i]
  leg3 = Kisi3[i]
  leg4 = Kisi4[i]
  leg5 = Kisi5[i]
  print("Kisi 1 : " + str(i) + " = " + str(leg1) +".")
  print("Kisi 2 : " +str(i) + " = " + str(leg2) +".")
  print("Kisi 3 : " +str(i) + " = " + str(leg3) +".")
  print("Kisi 4 : " +str(i) + " = " + str(leg4) +".")
  print("Kisi 5 : " +str(i) + " = " + str(leg5) +".")
# Out:
# Kisi 1 : Mezuniyet = ÖnLisans.
# Kisi 2 : Mezuniyet = YüksekLisans.
# Kisi 3 : Mezuniyet = ÖnLisans.
# Kisi 4 : Mezuniyet = ÖnLisans.
# Kisi 5 : Mezuniyet = YüksekLisans.
# Kisi 1 : NotDurumu = 2.5.
# Kisi 2 : NotDurumu = 3.2.
# Kisi 3 : NotDurumu = 4.
# Kisi 4 : NotDurumu = 3.5.
# Kisi 5 : NotDurumu = 3.8.
# Kisi 1 : Mesleği = Yazılımcı.
# Kisi 2 : Mesleği = Yazılımcı.
# Kisi 3 : Mesleği = Yazılımcı.
# Kisi 4 : Mesleği = Yazılımcı.
# Kisi 5 : Mesleği = Yazılımcı.
